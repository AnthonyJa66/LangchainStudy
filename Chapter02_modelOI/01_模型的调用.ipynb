# %% [markdown]
# #1、模型调用的分类
#
# 角度1：按照模型功能的不同
#
# 非对话模型：LLMs、Text Model
#
# 对话模型：Chat Model
#
# 嵌入模型：Embedding Models
#
# 角度2：模型调用时，几个重要参数的书写位置的不同：
#
# 硬编码：写在代码文件中
#
# 使用环境变量
#
# 使用配置文件（ 推荐 ）
#
# 角度3：具体API的调用
#
# OpenAI提供的API
#
# 其它大模型自家提供的API
#
# LangChain的统一方式调用API（ 推荐 ）

# %% [markdown]
# 方式一——通过获取.ven的参数对baseurl和apikey进行赋值

# %%
import os
import dotenv
from langchain_openai import ChatOpenAI

from chapter01_summary.test import response

dotenv.load_dotenv()

###########核心代码############
#llm = OpenAI()#纯文本补全模型
llm = ChatOpenAI(
    model="qwen3.6-flash",
    api_key=os.getenv("DASHSCOPE_API_KEY"),
    base_url=os.getenv("DASHSCOPE_BASE_URL"),

)  #对话模型
str = llm.invoke("写一首关于春天的诗")  # 直接输入字符串
#print(str)
print(str.content)
# Out:
# 《春信》
#
# 东风过处柳初黄，细雨无声润野塘。
# 燕剪晴光穿旧巷，桃燃春色换新妆。
# 溪冰渐解鸣幽谷，地暖轻催蛰梦长。
# 莫负韶光行乐处，一川芳草向斜阳。

# %% [markdown]
# 方式二——通过获取.ven的参数预设环境变量，减少对baseurl和apikey的赋值

# %%
import os
import dotenv
from langchain_openai import ChatOpenAI

dotenv.load_dotenv()
os.environ["OPENAI_API_KEY"] = os.getenv("DASHSCOPE_API_KEY")
os.environ["OPENAI_BASE_URL"] = os.getenv("DASHSCOPE_BASE_URL")

###########核心代码############
#llm = OpenAI()#纯文本补全模型
llm = ChatOpenAI(
    model="qwen3.6-flash",
    temperature=0.7,
    max_tokens=256,
)  #对话模型

str = llm.invoke("写一首关于春天的诗")  # 直接输入字符串

#print(str)
print(str.content)
# Out:
# 《春日即景》
#
# 东风暗度小窗纱，
# 细雨无声润物华。
# 燕剪轻云归旧垒，
# 溪融残雪起新芽。
# 桃腮带露含春笑，
# 麦浪随风漫野斜。
# 莫负韶光行乐处，
# 且将诗思寄桑麻。
#
# 注：本诗依七言律诗体例，押平水韵“下平六麻”。全篇以风、雨、燕、溪、桃、麦为序，由微至广铺展春之生机；尾联转人事，寄寓惜时向自然、以诗心伴岁华之意。如需调整风格（如现代自由诗、词牌体或儿童谣曲），可告知具体偏好。

# %% [markdown]
# 方式三——直接设置model、apikey和baseurl

# %%
import os
from langchain_openai import ChatOpenAI

###########核心代码############
#llm = OpenAI()#纯文本补全模型
llm = ChatOpenAI(
    model="qwen3.6-flash",
    api_key="sk-5ec7dcxxxxx7ea3d7bd81",
    base_url="https://dashscope.aliyuncs.com/compatible-mode/v1",
    temperature=0.7,
    max_tokens=256,
)  #对话模型

str = llm.invoke("写一首关于夏天的诗")  # 直接输入字符串

#print(str)
print(str.content)

# %% [markdown]
# OpenAI格式

# %% [markdown]
# 非对话模型

# %%
from openai import OpenAI

client = OpenAI(
    api_key="sk-proj-oeLuCVlBIxxxxxYSaDwqGWImD2OgBtAC4UB456dbR_r8xoLcGuMNbQA",
    base_url="https://api.openai-proxy.org/v1")

response = client.completions.create(
    model="gpt-5.4-nano",
    prompt="请将以下英文翻译成中文：\n'Artificial intelligence will reshape the future.",
    temperature=0.7,
    max_tokens=256,
)
for event in response:
    print(event.delta)

# %% [markdown]
# 对话模型

# %%
from openai import OpenAI

client = OpenAI(api_key="sk-zD4CB2QxxxxxfQPxCUIfOFAk20ETV5B2VA",  #填写自己的api-key
                base_url="https://api.openai-proxy.org/v1")

completion = client.chat.completions.create(
    model="gpt-3.5-turbo",  # 对话模型
    messages=[
        {"role": "system", "content": "你是一个乐于助人的智能AI小助手"},
        {"role": "user", "content": "你好，请你介绍一下你自己"}
    ],
    max_tokens=150,
    temperature=0.5
)

print(completion.choices[0].message)

# %%
from openai import OpenAI
import os
import dotenv

dotenv.load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY1")
os.environ["OPENAI_BASE_URL"] = os.getenv("OPENAI_BASE_URL")

client = OpenAI()

response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "我是一位乐于助人的AI智能小助手"},
        {"role": "user", "content": "你好，请你介绍一下你自己。"}
    ]
)
print(response.choices[0])

# %% [markdown]
# 阿里百炼平台调用

# %% [markdown]
# 通过OpenAI sdk实现，pip install openai

# %%
import os
from openai import OpenAI

client = OpenAI(

    api_key=os.getenv("DASHSCOPE_API_KEY"),
    base_url=os.getenv("DASHSCOPE_BASE_URL")
)
completion = client.chat.completions.create(
    model="qwen3.6-flash",  # 此处以 deepseek-r1 为例，可按需更换模型名称。qwen3.6-flash
    #max_tokens=256,
    messages=[
        {'role': 'user', 'content': '中文回答：数字9.9和9.11谁大'}
    ]
)
# 通过reasoning_content字段打印思考过程
print("思考过程：")
print(completion.choices[0].message.reasoning_content)

# 通过content字段打印最终答案
print("最终答案：")
print(completion.choices[0].message.content)

# %% [markdown]
# 通过dashscope实现，可以不写baseurl，pip install dashscope

# %%
import os
import dashscope

messages = [
    {'role': 'user', 'content': '你是谁？'}
]
response = dashscope.Generation.call(

    api_key=os.getenv('DASHSCOPE_API_KEY'),
    model="deepseek-r1",  # 此处以 deepseek-r1 为例，可按需更换模型名称。
    messages=messages,
    # result_format参数不可以设置为"text"。
    result_format='message'
)
print("=" * 20 + "思考过程" + "=" * 20)
print(response.output.choices[0].message.reasoning_content)
print("=" * 20 + "最终答案" + "=" * 20)
print(response.output.choices[0].message.content)

# %%
from openai import OpenAI

client = OpenAI(
    api_key="bce-v3/ALTAK-3VYe3KThy5uTuFGwfqL5N/339b4865af079d853929349fdaa9b686c7482903",  # 千帆bearer token
    base_url="https://qianfan.baidubce.com/v2",  # 千帆域名
    #default_headers={"appid": "app-xxxxxx"}   # 用户在千帆上的appid，非必传
)

completion = client.chat.completions.create(
    model="ernie-4.0-turbo-8k", # 预置服务请查看模型列表，定制服务请填入API地址
    messages=[{'role': 'system', 'content': 'You are a helpful assistant.'},
              {'role': 'user', 'content': 'Hello！'}]
)

print(completion.choices[0].message)
# Out:
# ChatCompletionMessage(content="Hello! 😊 It's always nice to meet new people. How can I help you today? Whether you have a question, need advice, or just want to chat, I'm here for you!", refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None)
